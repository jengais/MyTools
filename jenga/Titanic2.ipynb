# %%
import pandas as pd
import numpy as np




train = pd.read_csv('titanic_train.csv')
test = pd.read_csv('titanic_test.csv')
gender_submission = pd.read_csv('titanic_gender_submission.csv')

# %%
train
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_size = train['Survived'].tolist()
missing_data = pd.DataFrame({'total_missing': train.isnull().sum(), 'perc_missing': (train.isnull().sum()/len(train_size))*100})
missing_data


test_size = train['Survived'].tolist()
missing_data_test = pd.DataFrame({'total_missing': test.isnull().sum(), 'perc_missing': (test.isnull().sum()/len(test_size))*100})
missing_data_test
# Out:
#              total_missing  perc_missing
# PassengerId              0      0.000000
# Pclass                   0      0.000000
# Name                     0      0.000000
# Sex                      0      0.000000
# Age                     86      9.652076
# SibSp                    0      0.000000
# Parch                    0      0.000000
# Ticket                   0      0.000000
# Fare                     1      0.112233
# Cabin                  327     36.700337
# Embarked                 0      0.000000

# %%
#train.describe()

# %%
y = train.Survived

# %%
y
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
X = train.drop(['Survived', 'PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
X

X_test = test.drop(['PassengerId', 'Name', 'Ticket', 'Cabin'], axis=1)
X_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0         3    male  34.5      0      0    7.8292        Q
# 1         3  female  47.0      1      0    7.0000        S
# 2         2    male  62.0      0      0    9.6875        Q
# 3         3    male  27.0      0      0    8.6625        S
# 4         3  female  22.0      1      1   12.2875        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 413       3    male   NaN      0      0    8.0500        S
# 414       1  female  39.0      0      0  108.9000        C
# 415       3    male  38.5      0      0    7.2500        S
# 416       3    male   NaN      0      0    8.0500        S
# 417       3    male   NaN      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
train_size = X['Sex'].tolist()
missing_data = pd.DataFrame({'total_missing': X.isnull().sum(), 'perc_missing': (X.isnull().sum()/len(train_size))*100})
missing_data


X_test_size = X_test['Sex'].tolist()
missing_data_test = pd.DataFrame({'total_missing': X_test.isnull().sum(), 'perc_missing': (X_test.isnull().sum()/len(X_test_size))*100})
missing_data_test
# Out:
#           total_missing  perc_missing
# Pclass                0      0.000000
# Sex                   0      0.000000
# Age                  86     20.574163
# SibSp                 0      0.000000
# Parch                 0      0.000000
# Fare                  1      0.239234
# Embarked              0      0.000000

# %%
age_avg = X['Age'].sum()/len(X['Age'])
age_avg = (round(age_avg))
age_avg

# age_avg = X['Fare'].sum()/len(X['Fare'])
# age_avg = (round(age_avg))
# age_avg

age_avg_test = X_test['Age'].sum()/len(X_test['Age'])
age_avg_test = (round(age_avg_test))
age_avg_test

# age_avg_test = X_test['Fare'].sum()/len(X_test['Fare'])
# age_avg_test = (round(age_avg_test))
# age_avg_test
# Out:
# 24

# %%
age_avg2 = X['Fare'].sum()/len(X['Fare'])
age_avg2 = (round(age_avg))
age_avg2

# age_avg = X['Fare'].sum()/len(X['Fare'])
# age_avg = (round(age_avg))
# age_avg

age_avg_test2 = X_test['Fare'].sum()/len(X_test['Fare'])
age_avg_test2 = (round(age_avg_test))
age_avg_test2

# age_avg_test = X_test['Fare'].sum()/len(X_test['Fare'])
# age_avg_test = (round(age_avg_test))
# age_avg_test
# Out:
# 24

# %%
X.Age.fillna(age_avg ,inplace = True)
X

X_test.Age.fillna(age_avg_test ,inplace = True)
X_test

X.Fare.fillna(0 ,inplace = True)
X

X_test.Fare.fillna(0 ,inplace = True)
X_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0         3    male  34.5      0      0    7.8292        Q
# 1         3  female  47.0      1      0    7.0000        S
# 2         2    male  62.0      0      0    9.6875        Q
# 3         3    male  27.0      0      0    8.6625        S
# 4         3  female  22.0      1      1   12.2875        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 413       3    male  24.0      0      0    8.0500        S
# 414       1  female  39.0      0      0  108.9000        C
# 415       3    male  38.5      0      0    7.2500        S
# 416       3    male  24.0      0      0    8.0500        S
# 417       3    male  24.0      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
train_size = X['Sex'].tolist()
missing_data = pd.DataFrame({'total_missing': X.isnull().sum(), 'perc_missing': (X.isnull().sum()/len(train_size))*100})
missing_data

X_test_size = X_test['Sex'].tolist()
missing_data_test = pd.DataFrame({'total_missing': X_test.isnull().sum(), 'perc_missing': (X_test.isnull().sum()/len(X_test_size))*100})
missing_data_test
# Out:
#           total_missing  perc_missing
# Pclass                0           0.0
# Sex                   0           0.0
# Age                   0           0.0
# SibSp                 0           0.0
# Parch                 0           0.0
# Fare                  0           0.0
# Embarked              0           0.0

# %%
X['Fare'] = (round(X['Fare']))
#X['Embarked'] = (round(X['Embarked']))
X
# Out:
#      Pclass  Sex  Age  SibSp  Parch  Fare Embarked
# 0         3    1   28      1      0   7.0        S
# 1         1    0   51      1      0  71.0        C
# 2         3    0   34      0      0   8.0        S
# 3         1    0   47      1      0  53.0        S
# 4         3    1   47      0      0   8.0        S
# ..      ...  ...  ...    ...    ...   ...      ...
# 886       2    1   35      0      0  13.0        S
# 887       1    0   24      0      0  30.0        S
# 888       3    0   31      1      2  23.0        S
# 889       1    1   34      0      0  30.0        C
# 890       3    1   42      0      0   8.0        Q
#
# [891 rows x 7 columns]

# %%
X
X_test
# Out:
#      Pclass     Sex   Age  SibSp  Parch      Fare Embarked
# 0         3    male  34.5      0      0    7.8292        Q
# 1         3  female  47.0      1      0    7.0000        S
# 2         2    male  62.0      0      0    9.6875        Q
# 3         3    male  27.0      0      0    8.6625        S
# 4         3  female  22.0      1      1   12.2875        S
# ..      ...     ...   ...    ...    ...       ...      ...
# 413       3    male  24.0      0      0    8.0500        S
# 414       1  female  39.0      0      0  108.9000        C
# 415       3    male  38.5      0      0    7.2500        S
# 416       3    male  24.0      0      0    8.0500        S
# 417       3    male  24.0      1      1   22.3583        C
#
# [418 rows x 7 columns]

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
X['Sex']=le.fit_transform(X['Sex'])
X['Age']=le.fit_transform(X['Age'])
X['Embarked']=le.fit_transform(X['Embarked'])
X['Fare']=le.fit_transform(X['Fare'])

X_test['Sex']=le.fit_transform(X_test['Sex'])
X_test['Age']=le.fit_transform(X_test['Age'])
X_test['Embarked']=le.fit_transform(X_test['Embarked'])
X_test['Fare']=le.fit_transform(X_test['Fare'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode(values, uniques, encode, check_unknown)
#     112         try:
# --> 113             res = _encode_python(values, uniques, encode)
#     114         except TypeError:
#
# ~\anaconda3\lib\site-packages\sklearn\preprocessing\_label.py in _encode_python(values, uniques, encode)
#      60     if uniques is None:
# ---> 61         uniques = sorted(set(values))
#      62         uniques = np.array(uniques, dtype=values.dtype)
#
# TypeError: '<' not supported between instances of 'str' and 'float'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3d7501d44770> in <module>
#       3 X['Sex']=le.fit_transform(X['Sex'])
# ...

# %%
X
X_test

# %%
X_test

# %%
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score


clf = GaussianNB()
clf.fit(X, y)

print(clf.predict(X_test))
test_pred = clf.predict(X_test)
train_pred = clf.predict(X)

train_acc = accuracy_score(y, train_pred)

print("train_acc: ", train_acc)

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()
clf.fit(X, y)

print(clf.predict(X_test))
test_pred = clf.predict(X_test)
train_pred = clf.predict(X)

train_acc = accuracy_score(y, train_pred)

print("train_acc: ", train_acc)

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier()
clf.fit(X, y)

print(clf.predict(X_test))
test_pred = clf.predict(X_test)
train_pred = clf.predict(X)

train_acc = accuracy_score(y, train_pred)

print("train_acc: ", train_acc)

# %%
# df3 = pd.read_csv("titanic_gender_submission.csv")
# df3['Survived'] = test_pred

# df3.to_csv('Titanic2.5.csv', index = False)
