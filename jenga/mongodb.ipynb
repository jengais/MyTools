# %%
from pymongo import MongoClient
client = MongoClient()
client = MongoClient('localhost', 27017)


print('here')

mydatabase = client['my_mongo_db']

mycollection = mydatabase['myTable']

rec = {
        'title': 'MongoDB and Python', 
        'description': 'MongoDB is no SQL database', 
        'tags': ['mongodb', 'database', 'NoSQL'], 
        'viewers': 104 
    }


rec = mydatabase.myTable.insert_one({'title': [1,2,3]})

# for i in mydatabase.myTable.find({'title': 'MongoDB and Python'}):
#     print(i)
# Out:
# here
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9616/282204535.py in <module>
#      18
#      19
# ---> 20 rec = mydatabase.myTable.insert_one({'title': [1,2,3]})
#      21
#      22 # for i in mydatabase.myTable.find({'title': 'MongoDB and Python'}):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     540         write_concern = self._write_concern_for(session)
#     541         return InsertOneResult(
# --> 542             self._insert_one(
#     543                 document,
#     544                 ordered=True,
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, write_concern, op_id, bypass_doc_val, session)
#     492             _check_write_command_response(result)
#     493
# --> 494         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     495
#     496         if not isinstance(doc, RawBSONDocument):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1383     def _retryable_write(self, retryable, func, session):
#    1384         """Internal retryable write helper."""
# -> 1385         with self._tmp_session(session) as s:
#    1386             return self._retry_with_session(retryable, func, s, None)
#    1387
#
# c:\Users\jenga\anaconda3\lib\contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1654             return
#    1655
# -> 1656         s = self._ensure_session(session)
#    1657         if s:
#    1658             try:
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1641             # Don't make implicit sessions causally consistent. Applications
#    1642             # should always opt-in.
# -> 1643             return self.__start_session(True, causal_consistency=False)
#    1644         except (ConfigurationError, InvalidOperation):
#    1645             # Sessions not supported.
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1592     def __start_session(self, implicit, **kwargs):
#    1593         # Raises ConfigurationError if sessions are not supported.
# -> 1594         server_session = self._get_server_session()
#    1595         opts = client_session.SessionOptions(**kwargs)
#    1596         return client_session.ClientSession(self, server_session, opts, implicit)
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1627     def _get_server_session(self):
#    1628         """Internal: start or resume a _ServerSession."""
# -> 1629         return self._topology.get_server_session()
#    1630
#    1631     def _return_server_session(self, server_session, lock):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     532             # Sessions are always supported in load balanced mode.
#     533             if not self._settings.load_balanced:
# --> 534                 session_timeout = self._check_session_support()
#     535             else:
#     536                 # Sessions never time out in load balanced mode.
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in _check_session_support(self)
#     518                     )
#     519             elif not self._description.readable_servers:
# --> 520                 self._select_servers_loop(
#     521                     readable_server_selector, self._settings.server_selection_timeout, None
#     522                 )
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     221             # No suitable servers.
#     222             if timeout == 0 or now > end_time:
# --> 223                 raise ServerSelectionTimeoutError(
#     224                     "%s, Timeout: %ss, Topology Description: %r"
#     225                     % (self._error_message(selector), timeout, self.description)
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение, Timeout: 30s, Topology Description: <TopologyDescription id: 62279b91c7b9b0f83b3a72af, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение')>]>

# %%
# importing module
from pymongo import MongoClient
  
# creation of MongoClient
client=MongoClient()
  
# Connect with the portnumber and host
client = MongoClient('mongodb://localhost:27017/')
  
# Access database
mydatabase = client['name_of_the_database']
  
# Access collection of the database
mycollection=mydatabase['myTable']
  
# dictionary to be added in the database
rec={
'title': 'MongoDB and Python', 
'description': 'MongoDB is no SQL database', 
'tags': ['mongodb', 'database', 'NoSQL'], 
'viewers': 104 
}
  
# inserting the data in the database
rec = mydatabase.myTable.insert_one(rec)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9616/3085361130.py in <module>
#      23
#      24 # inserting the data in the database
# ---> 25 rec = mydatabase.myTable.insert_one(rec)
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\collection.py in insert_one(self, document, bypass_document_validation, session)
#     540         write_concern = self._write_concern_for(session)
#     541         return InsertOneResult(
# --> 542             self._insert_one(
#     543                 document,
#     544                 ordered=True,
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\collection.py in _insert_one(self, doc, ordered, check_keys, write_concern, op_id, bypass_doc_val, session)
#     492             _check_write_command_response(result)
#     493
# --> 494         self.__database.client._retryable_write(acknowledged, _insert_command, session)
#     495
#     496         if not isinstance(doc, RawBSONDocument):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_write(self, retryable, func, session)
#    1383     def _retryable_write(self, retryable, func, session):
#    1384         """Internal retryable write helper."""
# -> 1385         with self._tmp_session(session) as s:
#    1386             return self._retry_with_session(retryable, func, s, None)
#    1387
#
# c:\Users\jenga\anaconda3\lib\contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _tmp_session(self, session, close)
#    1654             return
#    1655
# -> 1656         s = self._ensure_session(session)
#    1657         if s:
#    1658             try:
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _ensure_session(self, session)
#    1641             # Don't make implicit sessions causally consistent. Applications
#    1642             # should always opt-in.
# -> 1643             return self.__start_session(True, causal_consistency=False)
#    1644         except (ConfigurationError, InvalidOperation):
#    1645             # Sessions not supported.
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in __start_session(self, implicit, **kwargs)
#    1592     def __start_session(self, implicit, **kwargs):
#    1593         # Raises ConfigurationError if sessions are not supported.
# -> 1594         server_session = self._get_server_session()
#    1595         opts = client_session.SessionOptions(**kwargs)
#    1596         return client_session.ClientSession(self, server_session, opts, implicit)
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _get_server_session(self)
#    1627     def _get_server_session(self):
#    1628         """Internal: start or resume a _ServerSession."""
# -> 1629         return self._topology.get_server_session()
#    1630
#    1631     def _return_server_session(self, server_session, lock):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in get_server_session(self)
#     532             # Sessions are always supported in load balanced mode.
#     533             if not self._settings.load_balanced:
# --> 534                 session_timeout = self._check_session_support()
#     535             else:
#     536                 # Sessions never time out in load balanced mode.
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in _check_session_support(self)
#     518                     )
#     519             elif not self._description.readable_servers:
# --> 520                 self._select_servers_loop(
#     521                     readable_server_selector, self._settings.server_selection_timeout, None
#     522                 )
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     221             # No suitable servers.
#     222             if timeout == 0 or now > end_time:
# --> 223                 raise ServerSelectionTimeoutError(
#     224                     "%s, Timeout: %ss, Topology Description: %r"
#     225                     % (self._error_message(selector), timeout, self.description)
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение, Timeout: 30s, Topology Description: <TopologyDescription id: 62279bd2c7b9b0f83b3a72b2, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение')>]>

# %%
from pymongo import MongoClient
client = MongoClient('localhost', 27017)
print(client.list_database_names())
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_9616/3026917916.py in <module>
#       1 from pymongo import MongoClient
#       2 client = MongoClient('localhost', 27017)
# ----> 3 print(client.list_database_names())
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in list_database_names(self, session)
#    1742         .. versionadded:: 3.6
#    1743         """
# -> 1744         return [doc["name"] for doc in self.list_databases(session, nameOnly=True)]
#    1745
#    1746     def drop_database(self, name_or_database, session=None):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in list_databases(self, session, **kwargs)
#    1724         cmd.update(kwargs)
#    1725         admin = self._database_default_options("admin")
# -> 1726         res = admin._retryable_read_command(cmd, session=session)
#    1727         # listDatabases doesn't return a cursor (yet). Fake one.
#    1728         cursor = {
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\database.py in _retryable_read_command(self, command, value, check, allowable_errors, read_preference, codec_options, session, **kwargs)
#     698             )
#     699
# --> 700         return self.__client._retryable_read(_cmd, read_preference, session)
#     701
#     702     def _list_collections(self, sock_info, secondary_okay, session, read_preference, **kwargs):
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _retryable_read(self, func, read_pref, session, address, retryable)
#    1348         while True:
#    1349             try:
# -> 1350                 server = self._select_server(read_pref, session, address=address)
#    1351                 with self._secondaryok_for_server(read_pref, server, session) as (
#    1352                     sock_info,
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\mongo_client.py in _select_server(self, server_selector, session, address)
#    1174                     raise AutoReconnect("server %s:%d no longer available" % address)
#    1175             else:
# -> 1176                 server = topology.select_server(server_selector)
#    1177             return server
#    1178         except PyMongoError as exc:
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     245     def select_server(self, selector, server_selection_timeout=None, address=None):
#     246         """Like select_servers, but choose a random server if several match."""
# --> 247         servers = self.select_servers(selector, server_selection_timeout, address)
#     248         if len(servers) == 1:
#     249             return servers[0]
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     206
#     207         with self._lock:
# --> 208             server_descriptions = self._select_servers_loop(selector, server_timeout, address)
#     209
#     210             return [self.get_server_by_address(sd.address) for sd in server_descriptions]
#
# c:\Users\jenga\anaconda3\lib\site-packages\pymongo\topology.py in _select_servers_loop(self, selector, timeout, address)
#     221             # No suitable servers.
#     222             if timeout == 0 or now > end_time:
# --> 223                 raise ServerSelectionTimeoutError(
#     224                     "%s, Timeout: %ss, Topology Description: %r"
#     225                     % (self._error_message(selector), timeout, self.description)
#
# ServerSelectionTimeoutError: localhost:27017: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение, Timeout: 30s, Topology Description: <TopologyDescription id: 6227a401c7b9b0f83b3a72b4, topology_type: Unknown, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [WinError 10061] Подключение не установлено, т.к. конечный компьютер отверг запрос на подключение')>]>
