# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn import metrics

df1=pd.read_csv("C:\\NewFoulder\SCE\שנה ב\סמסטר ב\מבוא לכריית נתונים\HW\\4\\train.csv").applymap(lambda x: x.lower() if type(x) == str else x)
df2=pd.read_csv("C:\\NewFoulder\SCE\שנה ב\סמסטר ב\מבוא לכריית נתונים\HW\\4\\test.csv").applymap(lambda x: x.lower() if type(x) == str else x)
head = df1.head()
print(head)
print()

#df1.applymap(lambda x: 0 if type(x) == None else float(x))
df1.fillna(0)

x = df2.loc[:, ['age', 'day']]
y = df2['class']
x = np.nan_to_num(x)
clf = DecisionTreeClassifier(criterion = 'entropy', max_depth=4)
clf = clf.fit(x,y)
y_pred = clf.predict(x)
print(y_pred)



x = df1.loc[:, ['age', 'day']]
y = df1['class']

clf = DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x,y)
res = clf.score(x,y)
print('Accurasy on [''age'', ''day''] is: {:.5f}%'.format(res))

x = df1.loc[:, ['age', 'campaign']]
y = df1['class']

clf = DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x,y)
res = clf.score(x,y)
print('Accurasy on [''age'', ''campaign''] is: {:.5f}%'.format(res))

x = df1.loc[:, ['age', 'previous']]
y = df1['class']

clf = DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x,y)
res = clf.score(x,y)
print('Accurasy on [''age'', ''previous''] is: {:.5f}%'.format(res))


x = df1.loc[:, ['age', 'balance']]
y = df1['class']
x = np.nan_to_num(x)
clf = DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x,y)
res = clf.score(x,y)
print('Accurasy on [''age'', ''balance''] is: {:.5f}%'.format(res))

x = df1.loc[:, ['age', 'duration']]
y = df1['class']
x = np.nan_to_num(x)
clf = DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x,y)
res = clf.score(x,y)
print('Accurasy on [''age'', ''duration''] is: {:.5f}%'.format(res))

x = df1.loc[:, ['balance', 'duration']]
y = df1['class']
x = np.nan_to_num(x)
clf = DecisionTreeClassifier(criterion = 'entropy')
clf = clf.fit(x,y)
res = clf.score(x,y)
print('Accurasy on [''balance'', ''duration''] is: {:.5f}%'.format(res))


#cross_val_score(clf, df1,y)
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no   2143.0     yes   no
# 1   44    technician   single  secondary      no     29.0     yes   no
# 2   33  entrepreneur  married  secondary      no      2.0     yes  yes
# 3   47   blue-collar  married    unknown      no   1506.0     yes   no
# 4   33       unknown   single    unknown      no      1.0      no   no
#
#    contact  day month  duration  campaign  previous poutcome class
# 0  unknown    5   may     261.0         1         0  unknown    no
# 1  unknown    5   may     151.0         1         0  unknown    no
# 2  unknown    5   may      76.0         1         0  unknown    no
# 3  unknown    5   may      92.0         1         0  unknown    no
# 4  unknown    5   may     198.0         1         0  unknown    no
#
# ['yes' 'yes' 'yes' ... 'yes' 'yes' 'yes']
# Accurasy on [age, day] is: 0.91517%
# Accurasy on [age, campaign] is: 0.91285%
# ...
