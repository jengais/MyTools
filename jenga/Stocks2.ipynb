# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("C:\\Users\jenga\Desktop\Stocks\Stocks\AT&T Inc. (T)\T.csv")
df_div = pd.read_csv("C:\\Users\jenga\Desktop\Stocks\Stocks\AT&T Inc. (T)\T_div.csv")

# %%
df
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2016-10-07  39.220001  39.290001  38.709999  38.869999  29.197472
# 1     2016-10-10  38.930000  39.200001  38.209999  39.009998  29.302626
# 2     2016-10-11  38.939999  39.380001  38.599998  39.099998  29.370237
# 3     2016-10-12  39.150002  39.490002  39.060001  39.330002  29.543003
# 4     2016-10-13  39.279999  39.480000  39.020000  39.369999  29.573046
# ...          ...        ...        ...        ...        ...        ...
# 1253  2021-09-30  27.480000  27.510000  27.010000  27.010000  27.010000
# 1254  2021-10-01  27.139999  27.400000  27.010000  27.160000  27.160000
# 1255  2021-10-04  27.240000  27.459999  27.090000  27.250000  27.250000
# 1256  2021-10-05  27.299999  27.480000  27.170000  27.350000  27.350000
# 1257  2021-10-06  27.260000  27.334999  26.969999  27.309999  27.309999
#
#         Volume
# 0     19172000
# 1     19020700
# 2     22314900
# 3     17179900
# 4     17546600
# ...

# %%
stocks = {'Stock Name': ['AT&T Inc.'],
          'Symbol': ['T'],
          'Last Price': [26.77],
          'Price Target': [31.65],
          'Dividend': [2.08],
          'Div Yield%': [7.68],
          'Recomend Rating': [2.9],
          'PE Ratio': [0],
          'EPS': [-0.31],
          'Market Cap': [191138000000],
          'Total Debt': [208020000000],
          'Revenue': [176010000000],
          'Earnings': [-2160000000]
         }

stocks = pd.DataFrame(stocks)  
stocks
# Out:
#   Stock Name Symbol  Last Price  Price Target  Dividend  Div Yield%  \
# 0  AT&T Inc.      T       26.77         31.65      2.08        7.68
#
#    Recomend Rating  PE Ratio   EPS    Market Cap    Total Debt       Revenue  \
# 0              2.9         0 -0.31  191138000000  208020000000  176010000000
#
#      Earnings
# 0 -2160000000

# %%
priceToDiv = float(stocks['Last Price'][0]/stocks['Dividend'][0])
print('priceToDiv:', priceToDiv)

# print(stocks['Market Cap'][0])
# print(float(stocks['Market Cap'][0][:len(stocks['Market Cap'][0])-1])*1000000)
# print(float(stocks['Total Debt'][0][:len(stocks['Total Debt'][0])-1])*1000000)
# capDebt = int(float(stocks['Market Cap'][0][:len(stocks['Market Cap'][0])-1])*1000000)/int(float(stocks['Total Debt'][0][:len(stocks['Total Debt'][0])-1])*1000000)

capToDebt = float(stocks['Market Cap'][0]/stocks['Total Debt'][0])
print('capToDebt:', capToDebt)

priceToTarget = float(stocks['Price Target'][0]/stocks['Last Price'][0])
print('priceToTarget:', priceToTarget)
# Out:
# priceToDiv: 12.870192307692307
# capToDebt: 0.9188443418902029
# priceToTarget: 1.1822936122525214

# %%
# visualize stocks price for both companies
close = df['Close'].tolist()
date = df['Date'].tolist()
#close2 = jpm['Close'].tolist()
#date2 = jpm['Date'].tolist()
plt.plot(date, close/stocks['Dividend'][0]) 
plt.plot(date, close) 
plt.grid( linestyle='--', linewidth=1)
plt.legend(["AT&T"], loc ="upper right", markerfirst = True, numpoints=1)
plt.xlabel('Date')
plt.ylabel('Close price in USD')
plt.xticks(date[::90])
plt.title('AT&T  prices last 5 years')
plt.style.use('default')
plt.gcf().autofmt_xdate()
plt.show()

# %%
stocks2 = {'Stock Name': ['Abbott Laboratories'],
          'Symbol': ['ABT'],
          'Last Price': [118.39],
          'PE Ratio': [33.35],
          'EPS': [3.55],
          'Dividend': [1.80],
          'Div Yield%': [1.52],
          'Recomend Rating': [1.9],
          'Price Target': [132.28],
          'Market Cap': [209884000000],
          'Revenue': [40230000000],
          'Earnings': [6340000000],
          'Total Debt': [18500000000]
         }

stocks = stocks.append(stocks2, ignore_index = True)
stocks
# Out:
#               Stock Name Symbol Last Price Price Target Dividend Div Yield%  \
# 0              AT&T Inc.      T      26.77        31.65     2.08       7.68
# 1  [Abbott Laboratories]  [ABT]   [118.39]     [132.28]    [1.8]     [1.52]
#
#   Recomend Rating PE Ratio     EPS      Market Cap     Total Debt  \
# 0             2.9        0   -0.31    191138000000   208020000000
# 1           [1.9]  [33.35]  [3.55]  [209884000000]  [18500000000]
#
#          Revenue      Earnings
# 0   176010000000   -2160000000
# 1  [40230000000]  [6340000000]

# %%
data = []
# stocks = {'Stock Name': ['AT&T Inc.'],
#           'Symbol': ['T'],
#           'Last Price': [26.77],
#           'PE Ratio': [0],
#           'EPS': [-0.31],
#           'Dividend': [2.08],
#           'Div Yield%': [7.68],
#           'Recomend Rating': [2.9],
#           'Price Target': [31.65],
#           'Market Cap': [191138000000],
#           'Revenue': [176010000000],
#           'Earnings': [-2160000000],
#           'Total Debt': [208020000000]
#          }

data.append(['Abbott Laboratories','ABT',118.39,33.35,3.55,1.80,1.52,1.9,132.28,209884000000,40230000000,6340000000,18500000000])
data.append(['AbbVie Inc.','ABBV',111.18,29.98,3.71,5.20,4.68,2,127.01,196480000000,53730000000,6600000000,82160000000])
data.append(['Alliant Energy Corporation','LNT',55.96,22.38,2.50,1.61 ,2.88,2.5,61.56,14000000000,3460000000,625000000,7310000000])
data.append(['Altria Group, Inc.','MO',46.73,19.11,2.44,3.60 ,7.70,2.2,55.23,86170000000,21230000000,4540000000,28240000000])
data.append(['American International Group, Inc.','AIG',57.61,12.02,4.79,1.28 ,2.22,2.2,58.67,49270000000,44340000000,4180000000,35730000000])
data.append(['Apple Inc. ','AAPL',142.90,27.98,5.11,0.88,0.62,1.9,167.92,2360000000000,347160000000,86800000000,135490000000])
data.append(['AT&T Inc.','T',26.77,0,-0.31,2.08,7.68,2.9,31.65,191138000000,176010000000,-2160000000,208020000000])
data.append(['Bristol-Myers Squibb Company','BMY',57.26,0,-2.26,1.96,3.42,1.9,79.89,127240000000,44380000000,-5080000000,46290000000])
data.append(['CenterPoint Energy, Inc.','CNP',25.54,18.89,1.35,0.68 ,2.66,1.9,27.92,15140000000,7970000000,781000000,16160000000])
data.append(['Chevron Corporation','CVX',108.05,57.35,1.88,5.36 ,4.96,2.3,122.40,208960000000,116030000000,3590000000,43020000000])
data.append(['Comcast Corporation','CMCSA',54.70,20.40,2.68,1.00 ,1.83,1.9,67.05,251060000000,108990000000,12470000000,103750000000])
data.append(['Consolidated Edison, Inc.','ED',73.47,22.32,3.29,3.10 ,4.22,3.5,75.11,25960000000,12940000000,1120000000,25000000000])
data.append(['Devon Energy Corporation','DVN',39.86,77.70,0.51,0.44 ,1.10,1.8,39.97,26990000000,7900000000,279000000,6790000000])
data.append(['Digital Realty Trust, Inc.','DLR',140.66,78.01,1.80,4.64 ,3.30,2.2,165.74,39910000000,4330000000,506580000,15470000000])
data.append(['Dow Inc.','DOW',58.71,10.74,5.47,2.80 ,4.77,2.7,67.86,43780000000,46190000000,4080000000,17750000000])
data.append(['Duke Energy Corporation','DUK',100.53,26.28,3.83,3.94 ,3.92,2.6,107.21,77340000000,23990000000,2880000000,67030000000])
data.append(['Nucor Corporation','NUE',97.97,9.76,10.03,1.62 ,1.65,2.5,109.18,28770000000,25990000000,3030000000,5570000000])
data.append(['Omnicom Group Inc.','OMC',75.22,12.09,6.22,2.80 ,3.72,2.6,83.31,16130000000,13960000000,1350000000,6340000000])
data.append(['ONEOK, Inc.','OKE',61.63,20.39,3.02,3.74 ,6.07,2.7,57.71,27470000000,11330000000,1350000000,14420000000])
data.append(['Oracle Corporation','ORCL',94.39,20.00,4.72,1.28 ,1.36,2.9,88.25,258030000000,40840000000,13950000000,82720000000])
data.append(['Packaging Corporation of America','PKG',139.13,20.82,6.68,4.00 ,2.88,2.8,148.20,13220000000,7090000000,631600000,2740000000])
data.append(['PepsiCo, Inc.','PEP',156.03,26.58,5.87,4.30 ,2.76,2.3,166.57,215730000000,76680000000,8140000000,41260000000])
data.append(['Pfizer Inc.','PFE',42.45,18.13,2.34,1.56 ,3.67,2.3,46.64,238000000000,55520000000,12320000000,39240000000])
data.append(['Philip Morris International Inc.','PM',95.35,16.82,5.67,5.00 ,5.24,2.1,110.27,148610000000,30070000000,8850000000,29160000000])
data.append(['Realty Income Corporation','O',67.20,67.81,0.99,2.83 ,4.21,2.2,78.31,26170000000,1730000000,361250000,9350000000])
data.append(['Regions Financial Corporation','RF',22.02,8.69,2.54,0.64 ,2.88,2.5,23.05,21020000000,6920000000,2450000000,4120000000])
data.append(['Simon Property Group, Inc.','SPG',132.08,28.54,4.63,6.00 ,4.54,2.1,150.00,43400000000,4690000000,1480000000,26740000000])
data.append(['SL Green Realty Corp.','SLG',74.05,17.91,4.13,3.64 ,4.92,2.9,79.24,4970000000,949730000,281060000,5320000000])
data.append(['Texas Instruments Incorporated','TXN',195.24,27.23,7.17,4.60 ,2.36,2.5,204.76,180250000000,16760000000,6700000000,6250000000])
data.append(['The Coca-Cola Company','KO',54.12,28.93,1.87,1.68 ,3.10,2.2,62.01,233620000000,36410000000,8080000000,42060000000])
data.append(['The Kraft Heinz Company','KHC',36.78,21.04,1.75,1.60 ,4.35,2.8,40.81,450000000,26390000000,2160000000,25310000000])
data.append(['The Williams Companies, Inc.','WMB',28.32,29.84,0.95,1.64 ,5.79,1.8,29.22,34410000000,8920000000,1150000000,23230000000])
data.append(['Wells Fargo & Company','WFC',48.00,12.85,3.73,0.80 ,1.67,2.3,50.81,197110000000,76440000000,15560000000,244550000000])
data.append(['Welltower Inc.','WELL',82.69,59.62,1.39,2.44 ,2.95,2.1,92.05,34940000000,4350000000,587120000,13960000000])
#data.append(['','',,,,,,,,,,,])


df = pd.DataFrame(data, columns=['Stock Name','Symbol','Last Price','PE Ratio','EPS','Dividend','Div Yield%','Recomend Rating','Price Target','Market Cap','Revenue','Earnings','Total Debt'])
df
# Out:
#                                      Stock Name Symbol  Last Price  PE Ratio  \
# 0                           Abbott Laboratories    ABT      118.39     33.35
# 1                                   AbbVie Inc.   ABBV      111.18     29.98
# 2                    Alliant Energy Corporation    LNT       55.96     22.38
# 3                            Altria Group, Inc.     MO       46.73     19.11
# 4            American International Group, Inc.    AIG       57.61     12.02
# 5                                   Apple Inc.    AAPL      142.90     27.98
# 6                                     AT&T Inc.      T       26.77      0.00
# 7                  Bristol-Myers Squibb Company    BMY       57.26      0.00
# 8                      CenterPoint Energy, Inc.    CNP       25.54     18.89
# 9                           Chevron Corporation    CVX      108.05     57.35
# 10                          Comcast Corporation  CMCSA       54.70     20.40
# ...

# %%
df.to_csv('StocksTable.csv', index = False)
