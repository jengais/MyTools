# %%
#pip install --upgrade ipykernel ipython

# %%
#pip install twint

# %%
#pip install nest_asyncio

# %%
#conda install git

# %%
#pip install --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint

# %%
import nest_asyncio
nest_asyncio.apply()

# %%
import twint
#https://github.com/twintproject/twint/wiki
a = twint.Config()
a.Username = 'YairNetanyahu'
a.Limit = 10
#a.Since = "2020-02-01"
a.Store_csv = True
a.Output =a.Username+".csv"
a.Lang="he"


# a.Search = "from:@santi_ABASCAL vox"

# a.User_full = True
# a.Pandas = True

# %%
twint.run.Search(a)
# Out:
# 1504857192087891969 2022-03-18 18:28:08 +0200 <YairNetanyahu> אני צופה הרבה בערוץ @FoxNews.זהו ערוץ החדשות הנצפה באמריקה. בהפסקת הפרסומות פתאום קלטתי את הפרומו הזה:  https://t.co/VRHjRR51N0
# 1504775122976231426 2022-03-18 13:02:01 +0200 <YairNetanyahu> תודה ליברמן! תודה בנט! תודה לפיד!  https://t.co/aCYOFj2WC8
# 1504765111977889793 2022-03-18 12:22:14 +0200 <YairNetanyahu> מוזמנים ללחוץ על הלינק ולהאזין לתוכנית השבועית ברדיו @IsraelGaley ! שבת שלום!   https://t.co/Pyec3qZOQv  https://t.co/PCj4cRkPNF
# 1504502937883754510 2022-03-17 19:00:27 +0200 <YairNetanyahu> ממשלת שמד  https://t.co/ngXdTRj0hO
# 1504406155866554371 2022-03-17 12:35:52 +0200 <YairNetanyahu>  https://t.co/rWtc3vnMNd
# 1504362409682771968 2022-03-17 09:42:02 +0200 <YairNetanyahu> Watch my interview to newsmax yesterday
# 1504202419269521412 2022-03-16 23:06:18 +0200 <YairNetanyahu> 🚨🚨🚨
# 1504201418948988929 2022-03-16 23:02:19 +0200 <YairNetanyahu> וזה עוד במרכז תל אביב
# 1504195362940198918 2022-03-16 22:38:15 +0200 <YairNetanyahu> פורים שמח! 🤡🎉 Happy Purim!  https://t.co/pyf7PJoUJm
# 1504094861095583749 2022-03-16 15:58:54 +0200 <YairNetanyahu> @attilus בבקשה  https://t.co/y954wCsAJ4
# 1504002101680250880 2022-03-16 09:50:18 +0200 <YairNetanyahu> אותה הונגריה שנתניהו טיפח את היחסים עימה, ולפיד ובנט מנסים להחריב
# 1503991361628000259 2022-03-16 09:07:38 +0200 <YairNetanyahu> ממשלת בובות של ממשל ביידן
# 1503827251510525957 2022-03-15 22:15:31 +0200 <YairNetanyahu> Northern Israel today! 📸❄️ צילום: רפאל נוה  https://t.co/kMt08a5RF3
# 1503764095618760708 2022-03-15 18:04:33 +0200 <YairNetanyahu> בעוד בנט ולפיד מפקירים את ישראל להשמדה ע״י אירן באמצעות הסכם הגרעין, חברינו הרפובליקנים בקונגרס ובסנאט נלחמים נגד ההסכם כמו אריות
# 1503761013329604625 2022-03-15 17:52:18 +0200 <YairNetanyahu> מזכיר את הכרטיסים לרכבת למקורבים של קסטנר
# 1503739732152532997 2022-03-15 16:27:44 +0200 <YairNetanyahu> שר החוץ האיראני טס למוסקבה וקיבל מה שהוא רוצה. בנט טס לפגוש את פוטין, ובמקום לסנדל את הסכם הגרעין המסכן את קיומה של ישראל, הוא התעסק באוקראינה...  https://t.co/uXTUh1cMZL
# 1503719574952460295 2022-03-15 15:07:39 +0200 <YairNetanyahu> אני בטוח שבנט דאג להכשיל את הסכם הגרעין בשיחותיו עם פוטין, כפי שהאיראנים דאגו שההסכם יעבור בשיחותיהם עם הרוסים. אה לא?
# 1503693503062323200 2022-03-15 13:24:03 +0200 <YairNetanyahu> &gt;&gt;וכי תיק 4000 הוא תיק תפור, עלילת דם, והפיכה. המסך בעצם קובר סופית את תיק 4000 ומוכיח שנתניהו צח כשלג.  הנה מה שערוץ התרעלה 12 שידר אתמול במהדורה המרכזית לנוכח הגילוי המרעיש  הזה:
# 1503693499941756930 2022-03-15 13:24:02 +0200 <YairNetanyahu> במשך שנים ערוץ התעמולה 12 שידר כל ערב הבמהדורה המרכזית קטעי רכילויות שקריים, תמלילים חסרי חשיבות וכתבות שלמות על תיקי נתניהו, ושטף לציבור את המוח.  אתמול התרחשה רעידת אדמה. בבית המשפט נחשף מסמך מ2016 של המשנה ליועץ המשפטי לממשלה, מסמך המוכיח כי נתניהו פעל ללא דופי, &gt;&gt;  https://t.co/XDTmn33dQr
# 1503483460744364038 2022-03-14 23:29:25 +0200 <YairNetanyahu> מה הולך כאן!?  https://t.co/KBMoNn2yF2

# %%
import pandas as pd
df = pd.read_csv("YairNetanyahu.csv")
df
# Out:
#                       id      conversation_id  \
# 0    1504406155866554371  1504406155866554371
# 1    1504362409682771968  1504362409682771968
# 2    1504202419269521412  1504202419269521412
# 3    1504201418948988929  1504201418948988929
# 4    1504195362940198918  1504195362940198918
# ..                   ...                  ...
# 195  1503739732152532997  1503739732152532997
# 196  1503719574952460295  1503719574952460295
# 197  1503693503062323200  1503693499941756930
# 198  1503693499941756930  1503693499941756930
# 199  1503483460744364038  1503483460744364038
#
#                                          created_at        date      time  \
# 0    2022-03-17 12:35:52 ????????????? ????? (????)  2022-03-17  12:35:52
# 1    2022-03-17 09:42:02 ????????????? ????? (????)  2022-03-17  09:42:02
# 2    2022-03-16 23:06:18 ????????????? ????? (????)  2022-03-16  23:06:18
# 3    2022-03-16 23:02:19 ????????????? ????? (????)  2022-03-16  23:02:19
# 4    2022-03-16 22:38:15 ????????????? ????? (????)  2022-03-16  22:38:15
# ..                                              ...         ...       ...
# 195  2022-03-15 16:27:44 ????????????? ????? (????)  2022-03-15  16:27:44
# 196  2022-03-15 15:07:39 ????????????? ????? (????)  2022-03-15  15:07:39
# 197  2022-03-15 13:24:03 ????????????? ????? (????)  2022-03-15  13:24:03
# 198  2022-03-15 13:24:02 ????????????? ????? (????)  2022-03-15  13:24:02
# 199  2022-03-14 23:29:25 ????????????? ????? (????)  2022-03-14  23:29:25
#
#      timezone             user_id       username            name  place  ...  \
# 0         200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 1         200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 2         200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 3         200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 4         200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# ..        ...                 ...            ...             ...    ...  ...
# 195       200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 196       200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 197       200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 198       200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
# 199       200  876408437814558724  yairnetanyahu  Yair Netanyahu    NaN  ...
#
#     geo source user_rt_id user_rt retweet_id  reply_to  retweet_date  \
# 0   NaN    NaN        NaN     NaN        NaN        []           NaN
# 1   NaN    NaN        NaN     NaN        NaN        []           NaN
# 2   NaN    NaN        NaN     NaN        NaN        []           NaN
# 3   NaN    NaN        NaN     NaN        NaN        []           NaN
# 4   NaN    NaN        NaN     NaN        NaN        []           NaN
# ..   ..    ...        ...     ...        ...       ...           ...
# 195 NaN    NaN        NaN     NaN        NaN        []           NaN
# 196 NaN    NaN        NaN     NaN        NaN        []           NaN
# 197 NaN    NaN        NaN     NaN        NaN        []           NaN
# 198 NaN    NaN        NaN     NaN        NaN        []           NaN
# 199 NaN    NaN        NaN     NaN        NaN        []           NaN
#
#      translate trans_src trans_dest
# 0          NaN       NaN        NaN
# 1          NaN       NaN        NaN
# 2          NaN       NaN        NaN
# 3          NaN       NaN        NaN
# 4          NaN       NaN        NaN
# ..         ...       ...        ...
# 195        NaN       NaN        NaN
# 196        NaN       NaN        NaN
# 197        NaN       NaN        NaN
# 198        NaN       NaN        NaN
# 199        NaN       NaN        NaN
#
# [200 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 36 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               200 non-null    int64
#  1   conversation_id  200 non-null    int64
#  2   created_at       200 non-null    object
#  3   date             200 non-null    object
#  4   time             200 non-null    object
#  5   timezone         200 non-null    int64
#  6   user_id          200 non-null    int64
#  7   username         200 non-null    object
#  8   name             200 non-null    object
#  9   place            0 non-null      float64
#  10  tweet            200 non-null    object
#  11  language         200 non-null    object
#  12  mentions         200 non-null    object
#  13  urls             200 non-null    object
#  14  photos           200 non-null    object
#  15  replies_count    200 non-null    int64
#  16  retweets_count   200 non-null    int64
#  17  likes_count      200 non-null    int64
#  18  hashtags         200 non-null    object
#  19  cashtags         200 non-null    object
#  20  link             200 non-null    object
#  21  retweet          200 non-null    bool
#  22  quote_url        101 non-null    object
#  23  video            200 non-null    int64
#  24  thumbnail        79 non-null     object
#  25  near             0 non-null      float64
#  26  geo              0 non-null      float64
#  27  source           0 non-null      float64
#  28  user_rt_id       0 non-null      float64
#  29  user_rt          0 non-null      float64
#  30  retweet_id       0 non-null      float64
#  31  reply_to         200 non-null    object
#  32  retweet_date     0 non-null      float64
#  33  translate        0 non-null      float64
#  34  trans_src        0 non-null      float64
#  35  trans_dest       0 non-null      float64
# dtypes: bool(1), float64(11), int64(8), object(16)
# memory usage: 55.0+ KB

# %%
(df['photos'][4])
# Out:
# "['https://pbs.twimg.com/media/FN_5tNEXIAUgcs7.jpg']"

# %%
t = df['photos'][4][2:len(df['photos'][4])-2]
t
# Out:
# 'https://pbs.twimg.com/media/FN_5tNEXIAUgcs7.jpg'
