# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import time
from datetime import datetime 

start_time = datetime.now()

# %%
df1 = pd.read_csv("Desktop\Recommender Systems Project\MovieLens_Kaggle\\archive\genome_scores.csv")
df1
# Out:
#           movieId  tagId  relevance
# 0               1      1    0.02500
# 1               1      2    0.02500
# 2               1      3    0.05775
# 3               1      4    0.09675
# 4               1      5    0.14675
# ...           ...    ...        ...
# 11709763   131170   1124    0.58775
# 11709764   131170   1125    0.01075
# 11709765   131170   1126    0.01575
# 11709766   131170   1127    0.11450
# 11709767   131170   1128    0.02175
#
# [11709768 rows x 3 columns]

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11709768 entries, 0 to 11709767
# Data columns (total 3 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   movieId    int64
#  1   tagId      int64
#  2   relevance  float64
# dtypes: float64(1), int64(2)
# memory usage: 268.0 MB

# %%
df2 = pd.read_csv("Desktop\Recommender Systems Project\MovieLens_Kaggle\\archive\genome_tags.csv")
df2
# Out:
#       tagId           tag
# 0         1           007
# 1         2  007 (series)
# 2         3  18th century
# 3         4         1920s
# 4         5         1930s
# ...     ...           ...
# 1123   1124       writing
# 1124   1125         wuxia
# 1125   1126          wwii
# 1126   1127        zombie
# 1127   1128       zombies
#
# [1128 rows x 2 columns]

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1128 entries, 0 to 1127
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   tagId   1128 non-null   int64
#  1   tag     1128 non-null   object
# dtypes: int64(1), object(1)
# memory usage: 17.8+ KB

# %%
df3 = pd.read_csv("Desktop\Recommender Systems Project\MovieLens_Kaggle\\archive\link.csv")
df3
# Out:
#        movieId   imdbId    tmdbId
# 0            1   114709     862.0
# 1            2   113497    8844.0
# 2            3   113228   15602.0
# 3            4   114885   31357.0
# 4            5   113041   11862.0
# ...        ...      ...       ...
# 27273   131254   466713    4436.0
# 27274   131256   277703    9274.0
# 27275   131258  3485166  285213.0
# 27276   131260   249110   32099.0
# 27277   131262  1724965  286971.0
#
# [27278 rows x 3 columns]

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  27278 non-null  int64
#  1   imdbId   27278 non-null  int64
#  2   tmdbId   27026 non-null  float64
# dtypes: float64(1), int64(2)
# memory usage: 639.5 KB

# %%
df4 = pd.read_csv("Desktop\Recommender Systems Project\MovieLens_Kaggle\\archive\movie.csv")
df4
# Out:
#        movieId                               title  \
# 0            1                    Toy Story (1995)
# 1            2                      Jumanji (1995)
# 2            3             Grumpier Old Men (1995)
# 3            4            Waiting to Exhale (1995)
# 4            5  Father of the Bride Part II (1995)
# ...        ...                                 ...
# 27273   131254        Kein Bund für's Leben (2007)
# 27274   131256       Feuer, Eis & Dosenbier (2002)
# 27275   131258                  The Pirates (2014)
# 27276   131260                 Rentun Ruusu (2001)
# 27277   131262                    Innocence (2014)
#
#                                             genres
# 0      Adventure|Animation|Children|Comedy|Fantasy
# 1                       Adventure|Children|Fantasy
# 2                                   Comedy|Romance
# 3                             Comedy|Drama|Romance
# 4                                           Comedy
# ...

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27278 entries, 0 to 27277
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   movieId  27278 non-null  int64
#  1   title    27278 non-null  object
#  2   genres   27278 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 639.5+ KB

# %%
df5 = pd.read_csv("Desktop\Recommender Systems Project\MovieLens_Kaggle\\archive\\rating.csv")
df5
# Out:
#           userId  movieId  rating            timestamp
# 0              1        2     3.5  2005-04-02 23:53:47
# 1              1       29     3.5  2005-04-02 23:31:16
# 2              1       32     3.5  2005-04-02 23:33:39
# 3              1       47     3.5  2005-04-02 23:32:07
# 4              1       50     3.5  2005-04-02 23:29:40
# ...          ...      ...     ...                  ...
# 20000258  138493    68954     4.5  2009-11-13 15:42:00
# 20000259  138493    69526     4.5  2009-12-03 18:31:48
# 20000260  138493    69644     3.0  2009-12-07 18:10:57
# 20000261  138493    70286     5.0  2009-11-13 15:42:24
# 20000262  138493    71619     2.5  2009-10-17 20:25:36
#
# [20000263 rows x 4 columns]

# %%
df5.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000263 entries, 0 to 20000262
# Data columns (total 4 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   userId     int64
#  1   movieId    int64
#  2   rating     float64
#  3   timestamp  object
# dtypes: float64(1), int64(2), object(1)
# memory usage: 610.4+ MB

# %%
df6 = pd.read_csv("Desktop\Recommender Systems Project\MovieLens_Kaggle\\archive\\tag.csv")
df6
# Out:
#         userId  movieId            tag            timestamp
# 0           18     4141    Mark Waters  2009-04-24 18:19:40
# 1           65      208      dark hero  2013-05-10 01:41:18
# 2           65      353      dark hero  2013-05-10 01:41:19
# 3           65      521  noir thriller  2013-05-10 01:39:43
# 4           65      592      dark hero  2013-05-10 01:41:18
# ...        ...      ...            ...                  ...
# 465559  138446    55999        dragged  2013-01-23 23:29:32
# 465560  138446    55999  Jason Bateman  2013-01-23 23:29:38
# 465561  138446    55999         quirky  2013-01-23 23:29:38
# 465562  138446    55999            sad  2013-01-23 23:29:32
# 465563  138472      923  rise to power  2007-11-02 21:12:47
#
# [465564 rows x 4 columns]

# %%
df6.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 465564 entries, 0 to 465563
# Data columns (total 4 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   userId     465564 non-null  int64
#  1   movieId    465564 non-null  int64
#  2   tag        465548 non-null  object
#  3   timestamp  465564 non-null  object
# dtypes: int64(2), object(2)
# memory usage: 14.2+ MB

# %%
print('Time elapsed in (hh:mm:ss.ms): "{}"'.format(datetime.now() - start_time))
# Out:
# Time elapsed in (hh:mm:ss.ms): "0:00:09.566566"
